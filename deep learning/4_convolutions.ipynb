# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0 : 3.51275
# Minibatch accuracy: 6.2%
# Validation accuracy: 12.8%
# Minibatch loss at step 50 : 1.48703
# Minibatch accuracy: 43.8%
# Validation accuracy: 50.4%
# Minibatch loss at step 100 : 1.04377
# Minibatch accuracy: 68.8%
# Validation accuracy: 67.4%
# Minibatch loss at step 150 : 0.601682
# Minibatch accuracy: 68.8%
# Validation accuracy: 73.0%
# Minibatch loss at step 200 : 0.898649
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.8%
# Minibatch loss at step 250 : 1.3637
# Minibatch accuracy: 56.2%
# Validation accuracy: 75.4%
# Minibatch loss at step 300 : 1.41968
# Minibatch accuracy: 62.5%
# Validation accuracy: 76.0%
# Minibatch loss at step 350 : 0.300648
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.2%
# Minibatch loss at step 400 : 1.32092
# Minibatch accuracy: 56.2%
# Validation accuracy: 80.4%
# Minibatch loss at step 450 : 0.556701
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.4%
# Minibatch loss at step 500 : 1.65595
# Minibatch accuracy: 43.8%
# Validation accuracy: 79.6%
# Minibatch loss at step 550 : 1.06995
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.2%
# Minibatch loss at step 600 : 0.223684
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 650 : 0.619602
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.8%
# Minibatch loss at step 700 : 0.812091
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.4%
# Minibatch loss at step 750 : 0.276302
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.3%
# Minibatch loss at step 800 : 0.450241
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.3%
# Minibatch loss at step 850 : 0.137139
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.3%
# Minibatch loss at step 900 : 0.52664
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 950 : 0.623835
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.1%
# Minibatch loss at step 1000 : 0.243114
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.9%
# Test accuracy: 90.0%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
def train(num_steps,batch_size):

 
    patch_size = 5
    depth = 16
    num_hidden = 64
    report_step = num_steps//10
    graph = tf.Graph()

    with graph.as_default():

      # Input data.
      tf_train_dataset = tf.placeholder(
        tf.float32, shape=(batch_size, image_size, image_size, num_channels))
      tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
      tf_valid_dataset = tf.constant(valid_dataset)
      tf_test_dataset = tf.constant(test_dataset)

      # Variables.
      layer1_weights = tf.Variable(tf.truncated_normal(
          [patch_size, patch_size, num_channels, depth], stddev=0.1))
      layer1_biases = tf.Variable(tf.zeros([depth]))
      layer2_weights = tf.Variable(tf.truncated_normal(
          [patch_size, patch_size, depth, depth], stddev=0.1))
      layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
      layer3_weights = tf.Variable(tf.truncated_normal(
          [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
      layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
      layer4_weights = tf.Variable(tf.truncated_normal(
          [num_hidden, num_labels], stddev=0.1))
      layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

      # Model.
      def model(data):
            conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
            pooled = tf.nn.max_pool(conv, [1, 2, 2, 1], [
                                    1, 2, 2, 1], padding='SAME')
            hidden = tf.nn.relu(pooled + layer1_biases)
            conv = tf.nn.conv2d(hidden, layer2_weights, [
                                1, 1, 1, 1], padding='SAME')
            pooled = tf.nn.max_pool(conv, [1, 2, 2, 1], [
                                    1, 2, 2, 1], padding='SAME')
            hidden = tf.nn.relu(pooled + layer2_biases)
            shape = hidden.get_shape().as_list()
            reshape = tf.reshape(
                hidden, [-1, shape[1] * shape[2] * shape[3]])
            hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
            return tf.matmul(hidden, layer4_weights) + layer4_biases

      # Training computation.
      logits = model(tf_train_dataset)
      loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=tf_train_labels))

      # Optimizer.
    
      global_step = tf.Variable(0,trainable=False)
      learning_rate = tf.train.exponential_decay(.2,global_step,report_step,.9)
      optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss,global_step=global_step)

      # Predictions for the training, validation, and test data.
      train_prediction = tf.nn.softmax(logits)
      valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
      test_prediction = tf.nn.softmax(model(tf_test_dataset))


     

      with tf.Session(graph=graph) as session:
          tf.initialize_all_variables().run()
          print('Initialized')
          for step in range(num_steps):
            offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
            batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
            batch_labels = train_labels[offset:(offset + batch_size), :]
            feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
            _, l, predictions = session.run(
              [optimizer, loss, train_prediction], feed_dict=feed_dict)
            if (step % 50 == 0):
              print('Minibatch loss at step %d: %f' % (step, l))
              print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
              print('Validation accuracy: %.1f%%' % accuracy(
                valid_prediction.eval(), valid_labels))

          print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))

train(1001,64)
# Out:
# WARNING:tensorflow:From <ipython-input-7-b7209cd4ea5a>:70: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 3.369153
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.255871
# Minibatch accuracy: 57.8%
# Validation accuracy: 69.0%
# Minibatch loss at step 100: 0.829525
# Minibatch accuracy: 71.9%
# Validation accuracy: 79.2%
# Minibatch loss at step 150: 0.883257
# Minibatch accuracy: 71.9%
# Validation accuracy: 80.5%
# Minibatch loss at step 200: 0.478951
# Minibatch accuracy: 85.9%
# Validation accuracy: 82.2%
# Minibatch loss at step 250: 0.545131
# Minibatch accuracy: 82.8%
# Validation accuracy: 83.4%
# Minibatch loss at step 300: 0.531447
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.8%
# Minibatch loss at step 350: 0.755904
# Minibatch accuracy: 78.1%
# Validation accuracy: 84.6%
# Minibatch loss at step 400: 0.437177
# Minibatch accuracy: 89.1%
# Validation accuracy: 84.7%
# Minibatch loss at step 450: 0.337331
# Minibatch accuracy: 92.2%
# Validation accuracy: 84.9%
# Minibatch loss at step 500: 0.458897
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.2%
# Minibatch loss at step 550: 0.514823
# Minibatch accuracy: 82.8%
# Validation accuracy: 85.0%
# Minibatch loss at step 600: 0.592054
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.8%
# Minibatch loss at step 650: 0.541771
# Minibatch accuracy: 85.9%
# Validation accuracy: 85.8%
# Minibatch loss at step 700: 0.401080
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.7%
# Minibatch loss at step 750: 0.364659
# Minibatch accuracy: 95.3%
# Validation accuracy: 85.9%
# Minibatch loss at step 800: 0.472303
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.2%
# Minibatch loss at step 850: 0.546681
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.0%
# Minibatch loss at step 900: 0.541587
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.7%
# Minibatch loss at step 950: 0.421416
# Minibatch accuracy: 89.1%
# Validation accuracy: 86.5%
# Minibatch loss at step 1000: 0.466858
# Minibatch accuracy: 89.1%
# Validation accuracy: 86.5%
# Test accuracy: 93.0%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
def train(num_steps,batch_size):
    patch_size = 5
    depth = 16
    num_hidden = 100
    num_hidden_2 = 100
    report_step = num_steps//10

    graph = tf.Graph()

    with graph.as_default():

      # Input data.
        tf_train_dataset = tf.placeholder(
        tf.float32, shape=(batch_size, image_size, image_size, num_channels))
        tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
        tf_valid_dataset = tf.constant(valid_dataset)
        tf_test_dataset = tf.constant(test_dataset)
      # Variables.
        keep_prob = tf.placeholder(tf.float32)
        layer1_weights = tf.Variable(tf.truncated_normal(
            [patch_size, patch_size, num_channels, depth], stddev=0.1))
        layer1_biases = tf.Variable(tf.constant(.05,shape=[depth]))
        
        layer2_weights = tf.Variable(tf.truncated_normal(
            [patch_size, patch_size, depth, depth], stddev=0.1))
        layer2_biases = tf.Variable(tf.constant(.05, shape=[depth]))
        
        layer3_weights = tf.Variable(tf.truncated_normal(
            [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
        layer3_biases = tf.Variable(tf.constant(.05, shape=[num_hidden]))
        
        layer4_weights = tf.Variable(tf.truncated_normal(
            [num_hidden, num_hidden_2], stddev=0.1))
        layer4_biases = tf.Variable(tf.constant(.05, shape=[num_hidden_2]))

        layer5_weights = tf.Variable(tf.truncated_normal(
            [num_hidden_2, num_labels], stddev=0.1))
        layer5_biases = tf.Variable(tf.constant(.05, shape=[num_labels]))

        # generateLogit.
        def model(data):
            conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
            pooled = tf.nn.max_pool(conv, [1, 2, 2, 1], [
                                    1, 2, 2, 1], padding='SAME')
            hidden = tf.nn.relu(pooled + layer1_biases)
            droped = tf.nn.dropout(hidden,keep_prob)
            conv = tf.nn.conv2d(droped, layer2_weights, [
                                1, 1, 1, 1], padding='SAME')
            pooled = tf.nn.max_pool(conv, [1, 2, 2, 1], [
                                    1, 2, 2, 1], padding='SAME')
            hidden = tf.nn.relu(pooled + layer2_biases)
            droped = tf.nn.dropout(hidden,keep_prob)
            shape = hidden.get_shape().as_list()
            reshape = tf.reshape(
                droped, [-1, shape[1] * shape[2] * shape[3]])
            hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
            droped = tf.nn.dropout(hidden,keep_prob)
            hidden = tf.nn.relu(tf.matmul(hidden,layer4_weights)+layer4_biases)
            droped = tf.nn.dropout(hidden,keep_prob)
            return tf.matmul(droped, layer5_weights) + layer5_biases


      # Training computation.
        logits = model(tf_train_dataset)
        loss = tf.reduce_mean(
           tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=tf_train_labels))

      # Optimizer.
    
        global_step = tf.Variable(0,trainable=False)
        learning_rate = tf.train.exponential_decay(.2,global_step,report_step,.9)
        optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss,global_step=global_step)

        # Predictions for the training, validation, and test data.
        train_prediction = tf.nn.softmax(logits)
        valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
        test_prediction = tf.nn.softmax(model(tf_test_dataset))


     

        with tf.Session(graph=graph) as session:
            tf.initialize_all_variables().run()
            print('Initialized')
            for step in range(num_steps):
                offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
                batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
                batch_labels = train_labels[offset:(offset + batch_size), :]
                
           
               
                feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels,keep_prob:0.7}
                _, l, predictions = session.run(
                  [optimizer, loss, train_prediction], feed_dict=feed_dict)
                if (step % 50 == 0):
                  print('Minibatch loss at step %d: %f' % (step, l))
                  print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
                  print('Validation accuracy: %.1f%%' % accuracy(
                    valid_prediction.eval(feed_dict={tf_train_dataset : batch_data, tf_train_labels : batch_labels,keep_prob:1.0}), valid_labels))

            print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(feed_dict={tf_train_dataset : batch_data, tf_train_labels : batch_labels,keep_prob:1.0}), test_labels))
            
train(10001,128)
# Out:
# WARNING:tensorflow:From <ipython-input-9-968d3778d135>:83: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 2.416321
# Minibatch accuracy: 7.8%
# Validation accuracy: 9.5%
# Minibatch loss at step 50: 1.207137
# Minibatch accuracy: 60.9%
# Validation accuracy: 74.4%
# Minibatch loss at step 100: 0.748619
# Minibatch accuracy: 78.1%
# Validation accuracy: 81.0%
# Minibatch loss at step 150: 0.603585
# Minibatch accuracy: 83.6%
# Validation accuracy: 81.7%
# Minibatch loss at step 200: 0.591930
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.0%
# Minibatch loss at step 250: 0.558374
# Minibatch accuracy: 82.8%
# Validation accuracy: 83.9%
# Minibatch loss at step 300: 0.809636
# Minibatch accuracy: 68.0%
# Validation accuracy: 84.1%
# Minibatch loss at step 350: 0.560020
# Minibatch accuracy: 82.0%
# Validation accuracy: 84.2%
# Minibatch loss at step 400: 0.544173
# Minibatch accuracy: 83.6%
# Validation accuracy: 84.9%
# Minibatch loss at step 450: 0.583050
# Minibatch accuracy: 78.9%
# Validation accuracy: 85.0%
# Minibatch loss at step 500: 0.625817
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.8%
# Minibatch loss at step 550: 0.415539
# Minibatch accuracy: 85.2%
# Validation accuracy: 85.3%
# Minibatch loss at step 600: 0.392237
# Minibatch accuracy: 92.2%
# Validation accuracy: 85.6%
# Minibatch loss at step 650: 0.447016
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.9%
# Minibatch loss at step 700: 0.422873
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.0%
# Minibatch loss at step 750: 0.466698
# Minibatch accuracy: 85.2%
# Validation accuracy: 86.0%
# Minibatch loss at step 800: 0.422677
# Minibatch accuracy: 88.3%
# Validation accuracy: 86.3%
# Minibatch loss at step 850: 0.517449
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.3%
# Minibatch loss at step 900: 0.425499
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.4%
# Minibatch loss at step 950: 0.334124
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# Minibatch loss at step 1000: 0.436225
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# Minibatch loss at step 1050: 0.489820
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.7%
# Minibatch loss at step 1100: 0.602640
# Minibatch accuracy: 83.6%
# Validation accuracy: 86.7%
# Minibatch loss at step 1150: 0.459157
# Minibatch accuracy: 83.6%
# Validation accuracy: 87.0%
# Minibatch loss at step 1200: 0.583067
# Minibatch accuracy: 83.6%
# Validation accuracy: 86.9%
# Minibatch loss at step 1250: 0.539003
# Minibatch accuracy: 83.6%
# Validation accuracy: 86.8%
# Minibatch loss at step 1300: 0.438703
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.1%
# Minibatch loss at step 1350: 0.416722
# Minibatch accuracy: 86.7%
# Validation accuracy: 86.9%
# Minibatch loss at step 1400: 0.491929
# Minibatch accuracy: 83.6%
# Validation accuracy: 87.1%
# Minibatch loss at step 1450: 0.474989
# Minibatch accuracy: 82.8%
# Validation accuracy: 87.4%
# Minibatch loss at step 1500: 0.531825
# Minibatch accuracy: 82.0%
# Validation accuracy: 87.3%
# Minibatch loss at step 1550: 0.477911
# Minibatch accuracy: 83.6%
# Validation accuracy: 87.7%
# Minibatch loss at step 1600: 0.444509
# Minibatch accuracy: 85.2%
# Validation accuracy: 87.4%
# Minibatch loss at step 1650: 0.539481
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.6%
# Minibatch loss at step 1700: 0.400087
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.5%
# Minibatch loss at step 1750: 0.327202
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.6%
# Minibatch loss at step 1800: 0.437769
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.6%
# Minibatch loss at step 1850: 0.482231
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.3%
# Minibatch loss at step 1900: 0.535130
# Minibatch accuracy: 82.0%
# Validation accuracy: 87.8%
# Minibatch loss at step 1950: 0.544296
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.6%
# Minibatch loss at step 2000: 0.458511
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# Minibatch loss at step 2050: 0.424669
# Minibatch accuracy: 86.7%
# Validation accuracy: 87.8%
# Minibatch loss at step 2100: 0.504489
# Minibatch accuracy: 85.2%
# Validation accuracy: 88.0%
# Minibatch loss at step 2150: 0.538096
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.8%
# Minibatch loss at step 2200: 0.247861
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.2%
# Minibatch loss at step 2250: 0.311109
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.2%
# Minibatch loss at step 2300: 0.444607
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.9%
# Minibatch loss at step 2350: 0.504794
# Minibatch accuracy: 82.0%
# Validation accuracy: 88.1%
# Minibatch loss at step 2400: 0.505413
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.0%
# Minibatch loss at step 2450: 0.416818
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss at step 2500: 0.307291
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.3%
# Minibatch loss at step 2550: 0.503328
# Minibatch accuracy: 85.2%
# Validation accuracy: 88.2%
# Minibatch loss at step 2600: 0.304239
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.2%
# Minibatch loss at step 2650: 0.354341
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.3%
# Minibatch loss at step 2700: 0.374906
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.4%
# Minibatch loss at step 2750: 0.419862
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.4%
# Minibatch loss at step 2800: 0.314380
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.3%
# Minibatch loss at step 2850: 0.407615
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.6%
# Minibatch loss at step 2900: 0.404890
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.3%
# Minibatch loss at step 2950: 0.407682
# Minibatch accuracy: 89.8%
# Validation accuracy: 88.2%
# Minibatch loss at step 3000: 0.292695
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.6%
# Minibatch loss at step 3050: 0.343542
# Minibatch accuracy: 89.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 3100: 0.362343
# Minibatch accuracy: 86.7%
# Validation accuracy: 88.6%
# Minibatch loss at step 3150: 0.273065
# Minibatch accuracy: 93.0%
# Validation accuracy: 88.6%
# Minibatch loss at step 3200: 0.242444
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 3250: 0.392029
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.7%
# Minibatch loss at step 3300: 0.361631
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.0%
# Minibatch loss at step 3350: 0.544559
# Minibatch accuracy: 85.2%
# Validation accuracy: 88.7%
# Minibatch loss at step 3400: 0.480133
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.8%
# Minibatch loss at step 3450: 0.349352
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.8%
# Minibatch loss at step 3500: 0.361483
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.7%
# Minibatch loss at step 3550: 0.500848
# Minibatch accuracy: 86.7%
# Validation accuracy: 88.9%
# Minibatch loss at step 3600: 0.522214
# Minibatch accuracy: 85.2%
# Validation accuracy: 88.8%
# Minibatch loss at step 3650: 0.371898
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.0%
# Minibatch loss at step 3700: 0.346662
# Minibatch accuracy: 89.8%
# Validation accuracy: 88.9%
# Minibatch loss at step 3750: 0.360336
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.0%
# Minibatch loss at step 3800: 0.428269
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.2%
# Minibatch loss at step 3850: 0.508824
# Minibatch accuracy: 85.2%
# Validation accuracy: 89.0%
# Minibatch loss at step 3900: 0.370431
# Minibatch accuracy: 89.8%
# Validation accuracy: 88.9%
# Minibatch loss at step 3950: 0.329275
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.0%
# Minibatch loss at step 4000: 0.440746
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.0%
# Minibatch loss at step 4050: 0.355391
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.0%
# Minibatch loss at step 4100: 0.268476
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.0%
# Minibatch loss at step 4150: 0.427046
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss at step 4200: 0.385036
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.9%
# Minibatch loss at step 4250: 0.448735
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.0%
# Minibatch loss at step 4300: 0.313056
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.2%
# Minibatch loss at step 4350: 0.412739
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.2%
# Minibatch loss at step 4400: 0.348987
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.2%
# Minibatch loss at step 4450: 0.346366
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.0%
# Minibatch loss at step 4500: 0.494341
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.2%
# Minibatch loss at step 4550: 0.402486
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.1%
# Minibatch loss at step 4600: 0.325185
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.2%
# Minibatch loss at step 4650: 0.338334
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.9%
# Minibatch loss at step 4700: 0.442318
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.2%
# Minibatch loss at step 4750: 0.290975
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.3%
# Minibatch loss at step 4800: 0.359703
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.3%
# Minibatch loss at step 4850: 0.518052
# Minibatch accuracy: 83.6%
# Validation accuracy: 89.3%
# Minibatch loss at step 4900: 0.470101
# Minibatch accuracy: 85.2%
# Validation accuracy: 89.4%
# Minibatch loss at step 4950: 0.477962
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.3%
# Minibatch loss at step 5000: 0.553880
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.1%
# Minibatch loss at step 5050: 0.359945
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.3%
# Minibatch loss at step 5100: 0.360920
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.2%
# Minibatch loss at step 5150: 0.416159
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.4%
# Minibatch loss at step 5200: 0.420159
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 5250: 0.342212
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 5300: 0.432375
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.3%
# Minibatch loss at step 5350: 0.345586
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.5%
# Minibatch loss at step 5400: 0.343441
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.4%
# Minibatch loss at step 5450: 0.471703
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.5%
# Minibatch loss at step 5500: 0.390579
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.5%
# Minibatch loss at step 5550: 0.343178
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.5%
# Minibatch loss at step 5600: 0.359404
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# Minibatch loss at step 5650: 0.394193
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.7%
# Minibatch loss at step 5700: 0.363249
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# Minibatch loss at step 5750: 0.293587
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.5%
# Minibatch loss at step 5800: 0.530249
# Minibatch accuracy: 82.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 5850: 0.442380
# Minibatch accuracy: 85.2%
# Validation accuracy: 89.5%
# Minibatch loss at step 5900: 0.573648
# Minibatch accuracy: 82.0%
# Validation accuracy: 89.5%
# Minibatch loss at step 5950: 0.373777
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.7%
# Minibatch loss at step 6000: 0.370512
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# Minibatch loss at step 6050: 0.372634
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.6%
# Minibatch loss at step 6100: 0.366025
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.5%
# Minibatch loss at step 6150: 0.436814
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.6%
# Minibatch loss at step 6200: 0.296567
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.6%
# Minibatch loss at step 6250: 0.340279
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.5%
# Minibatch loss at step 6300: 0.407730
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.8%
# Minibatch loss at step 6350: 0.199480
# Minibatch accuracy: 94.5%
# Validation accuracy: 89.6%
# Minibatch loss at step 6400: 0.535430
# Minibatch accuracy: 82.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 6450: 0.450379
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.5%
# Minibatch loss at step 6500: 0.334764
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.4%
# Minibatch loss at step 6550: 0.311063
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.5%
# Minibatch loss at step 6600: 0.298219
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.6%
# Minibatch loss at step 6650: 0.440044
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.7%
# Minibatch loss at step 6700: 0.219440
# Minibatch accuracy: 93.0%
# Validation accuracy: 89.7%
# Minibatch loss at step 6750: 0.375647
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.7%
# Minibatch loss at step 6800: 0.344210
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# Minibatch loss at step 6850: 0.239992
# Minibatch accuracy: 93.0%
# Validation accuracy: 89.7%
# Minibatch loss at step 6900: 0.212003
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 6950: 0.401337
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.7%
# Minibatch loss at step 7000: 0.506933
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.6%
# Minibatch loss at step 7050: 0.345320
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.8%
# Minibatch loss at step 7100: 0.280480
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.6%
# Minibatch loss at step 7150: 0.401426
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.7%
# Minibatch loss at step 7200: 0.329280
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.7%
# Minibatch loss at step 7250: 0.231422
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.9%
# Minibatch loss at step 7300: 0.295595
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.7%
# Minibatch loss at step 7350: 0.406060
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.8%
# Minibatch loss at step 7400: 0.358170
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.5%
# Minibatch loss at step 7450: 0.314549
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.7%
# Minibatch loss at step 7500: 0.403576
# Minibatch accuracy: 85.2%
# Validation accuracy: 89.8%
# Minibatch loss at step 7550: 0.356988
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.9%
# Minibatch loss at step 7600: 0.343672
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.7%
# Minibatch loss at step 7650: 0.302567
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.9%
# Minibatch loss at step 7700: 0.287720
# Minibatch accuracy: 93.0%
# Validation accuracy: 89.8%
# Minibatch loss at step 7750: 0.305198
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# Minibatch loss at step 7800: 0.422337
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.7%
# Minibatch loss at step 7850: 0.385155
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.6%
# Minibatch loss at step 7900: 0.480563
# Minibatch accuracy: 83.6%
# Validation accuracy: 89.7%
# Minibatch loss at step 7950: 0.541158
# Minibatch accuracy: 85.2%
# Validation accuracy: 89.9%
# Minibatch loss at step 8000: 0.347816
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# Minibatch loss at step 8050: 0.385223
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.8%
# Minibatch loss at step 8100: 0.308499
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.8%
# Minibatch loss at step 8150: 0.209799
# Minibatch accuracy: 95.3%
# Validation accuracy: 89.9%
# Minibatch loss at step 8200: 0.234040
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.9%
# Minibatch loss at step 8250: 0.265566
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.0%
# Minibatch loss at step 8300: 0.228046
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.9%
# Minibatch loss at step 8350: 0.266770
# Minibatch accuracy: 93.0%
# Validation accuracy: 89.9%
# Minibatch loss at step 8400: 0.332980
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# Minibatch loss at step 8450: 0.394894
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.0%
# Minibatch loss at step 8500: 0.382105
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.8%
# Minibatch loss at step 8550: 0.393834
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.8%
# Minibatch loss at step 8600: 0.281297
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.9%
# Minibatch loss at step 8650: 0.279750
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.0%
# Minibatch loss at step 8700: 0.321721
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.9%
# Minibatch loss at step 8750: 0.426002
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.9%
# Minibatch loss at step 8800: 0.364203
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.0%
# Minibatch loss at step 8850: 0.357203
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.0%
