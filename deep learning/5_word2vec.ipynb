# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'originated', 'a', 'anarchism', 'term', 'as', 'of', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.636488
# Nearest to an: eisenstein, shouted, mcgill, veterans, clotting, libert, ills, impressively,
# Nearest to history: scarab, inappropriately, cereal, associations, lenat, discourages, cuyahoga, plaintiff,
# Nearest to s: schwa, roddenberry, creative, nuts, extensionality, brewery, str, thread,
# Nearest to not: strongholds, intricately, salinity, daddah, rgen, dubliners, beacon, cunt,
# Nearest to about: strings, demonstrators, macroeconomic, umi, greatly, abel, liguria, kevin,
# Nearest to more: spike, commentator, extraneous, pepper, transonic, amazed, hasse, experience,
# Nearest to during: recumbent, affidavit, covert, mauritanian, sears, centimetre, innocence, mites,
# Nearest to be: strauss, neurotransmitters, ane, attractors, succeeding, bucky, dias, commence,
# Nearest to as: win, shotgun, auditions, clavell, foundations, extracting, kn, tehran,
# Nearest to known: henotheistic, alford, naturalist, khuzestan, chemistry, impart, ska, celtic,
# Nearest to war: honoring, oses, netscape, relates, attica, lied, stv, lewd,
# Nearest to people: crono, dentists, assimilation, neolithic, orestes, patriarchs, nist, cowl,
# Nearest to these: inertia, piaget, polymer, septicemic, handful, punts, ripped, volhynia,
# Nearest to to: sidewise, truk, gasification, adjoining, syd, incompatible, friction, virtuosic,
# Nearest to this: westermann, desperate, sell, conciliar, thoth, supranational, leeuwenhoek, budd,
# Nearest to nine: vegeta, beauharnais, cofinal, teleological, topographic, relates, coeducational, representable,
# Average loss at step 2000: 4.361295
# Average loss at step 4000: 3.870405
# Average loss at step 6000: 3.794292
# Average loss at step 8000: 3.685557
# Average loss at step 10000: 3.618215
# Nearest to an: the, advised, lightbulb, shouted, involuntary, eisenstein, mcgill, vienne,
# Nearest to history: argand, construction, discourages, seminars, microeconomics, complicating, lovers, inorganic,
# Nearest to s: his, avoiding, isbn, acrylic, pointwise, dancing, roadmap, concealed,
# Nearest to not: intricately, strongholds, pact, it, they, toxins, ley, also,
# Nearest to about: greatly, strings, estimated, headwaters, demonstrators, requests, kevin, desserts,
# Nearest to more: spike, experience, divination, transonic, extraneous, bloody, pepper, ilyich,
# Nearest to during: recumbent, at, affidavit, covert, in, lis, mauritanian, probabilities,
# Nearest to be: have, is, was, anyone, compositional, by, refer, were,
# Nearest to as: respects, synthesized, single, rung, anoa, by, miocene, tehran,
# Nearest to known: moreno, homicidal, madre, well, yard, supercomputer, roasted, magnifying,
# Nearest to war: honoring, suspect, attica, relates, oses, episcopi, interestingly, stv,
# Nearest to people: lips, orestes, worthy, all, nist, dentists, pickups, apollonius,
# Nearest to these: believes, expressions, dictatorial, polymer, which, inertia, terminated, true,
# Nearest to to: sidewise, maskhadov, would, indies, not, misconduct, asturias, syd,
# Nearest to this: the, it, which, that, a, faculties, their, usurpers,
# Nearest to nine: eight, seven, six, five, zero, four, three, two,
# Average loss at step 12000: 3.604952
# Average loss at step 14000: 3.571269
# Average loss at step 16000: 3.406999
# Average loss at step 18000: 3.454896
# Average loss at step 20000: 3.545448
# Nearest to an: the, eisenstein, radical, shouted, lightbulb, involuntary, advised, mcgill,
# Nearest to history: argand, microeconomics, construction, discourages, lovers, complicating, cuyahoga, seminars,
# Nearest to s: isbn, major, taj, pointwise, refutes, yield, maslow, oracle,
# Nearest to not: also, to, they, pact, it, cheques, bassoons, toxins,
# Nearest to about: greatly, strings, kevin, estimated, desserts, requests, stripped, wind,
# Nearest to more: less, spike, experience, most, pepper, catabolism, syntax, divination,
# Nearest to during: at, recumbent, covert, probabilities, in, lis, innocence, affidavit,
# Nearest to be: have, been, by, was, refer, is, being, anyone,
# Nearest to as: single, daniell, gladius, fireplace, miocene, tehran, naiste, by,
# Nearest to known: well, used, madre, moreno, such, yard, sapporo, homicidal,
# Nearest to war: honoring, suspect, pristine, interestingly, middle, rehearsal, episcopi, diarist,
# Nearest to people: orestes, lips, all, westinghouse, apollonius, pickups, worthy, nist,
# Nearest to these: many, which, some, expressions, they, several, their, aramaic,
# Nearest to to: would, not, can, syd, gasification, may, stram, sidewise,
# Nearest to this: which, it, the, their, faculties, that, a, subsist,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Average loss at step 22000: 3.499569
# Average loss at step 24000: 3.488069
# Average loss at step 26000: 3.480672
# Average loss at step 28000: 3.478408
# Average loss at step 30000: 3.502309
# Nearest to an: involuntary, mcgill, drummers, prospectors, lightbulb, disrupting, radical, launches,
# Nearest to history: construction, microeconomics, argand, cuyahoga, essayists, ebro, member, seminars,
# Nearest to s: his, isbn, and, refutes, yield, whose, socializing, her,
# Nearest to not: they, caesium, cheques, there, always, never, it, hashes,
# Nearest to about: greatly, desserts, on, estimated, strings, requests, kevin, reruns,
# Nearest to more: less, most, very, spike, longer, rather, catabolism, brigadists,
# Nearest to during: in, at, after, recumbent, innocence, covert, through, lis,
# Nearest to be: been, have, refer, is, was, are, being, anyone,
# Nearest to as: beos, became, naiste, welwyn, using, by, fullmetal, preserved,
# Nearest to known: well, used, such, defined, moreno, described, madre, shatz,
# Nearest to war: bithynia, suspect, baxter, fronts, virgil, middle, interrupts, diarist,
# Nearest to people: orestes, lips, westinghouse, students, kanji, individuals, pickups, worthy,
# Nearest to these: many, some, which, several, they, both, such, their,
# Nearest to to: would, can, will, gasification, must, syd, could, may,
# Nearest to this: which, it, that, there, logged, the, not, mesh,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Average loss at step 32000: 3.501331
# Average loss at step 34000: 3.495081
# Average loss at step 36000: 3.451675
# Average loss at step 38000: 3.301657
# Average loss at step 40000: 3.434400
# Nearest to an: eisenstein, disrupting, isadora, mcgill, macos, neglect, repressive, speedway,
# Nearest to history: immunodeficiency, recipient, determining, clapton, longitudinal, argand, microeconomics, construction,
# Nearest to s: his, blueprints, schwa, her, zar, compulsion, synchronised, yield,
# Nearest to not: they, it, you, never, cheques, we, often, always,
# Nearest to about: greatly, strings, approximately, estimated, desserts, adriatic, wind, reduplication,
# Nearest to more: less, most, very, longer, rather, greater, spike, pepper,
# Nearest to during: after, at, through, against, within, before, since, innocence,
# Nearest to be: have, been, being, is, refer, are, was, anyone,
# Nearest to as: minimising, ethel, naiste, by, payloads, respects, warship, alta,
# Nearest to known: used, defined, such, moreno, well, described, sapporo, regarded,
# Nearest to war: bithynia, honoring, interrupts, haitians, middle, diarist, murdered, modernized,
# Nearest to people: individuals, students, lycos, lips, men, orestes, kanji, superlative,
# Nearest to these: many, some, several, both, they, such, which, those,
# Nearest to to: could, syd, would, may, can, virtuosic, deacons, must,
# Nearest to this: which, it, the, that, any, logged, another, subsist,
# Nearest to nine: eight, seven, six, five, four, zero, three, one,
# Average loss at step 42000: 3.435879
# Average loss at step 44000: 3.457355
# Average loss at step 46000: 3.443731
# Average loss at step 48000: 3.351500
# Average loss at step 50000: 3.379352
# Nearest to an: another, mcgill, eisenstein, extant, radical, speedway, numeration, neglect,
# Nearest to history: determining, encyclopedia, essence, rulebook, frans, cuyahoga, recipient, justice,
# Nearest to s: isbn, synchronised, his, whose, analyte, although, ssp, maslow,
# Nearest to not: they, never, always, you, cezanne, now, almost, it,
# Nearest to about: greatly, estimated, strings, approximately, fostered, fg, pyrimidine, ranger,
# Nearest to more: less, most, longer, very, spike, rather, greater, quite,
# Nearest to during: after, at, in, through, but, before, within, against,
# Nearest to be: have, been, refer, being, become, are, was, is,
# Nearest to as: beos, became, warship, naiste, battling, dissenters, wassily, ethel,
# Nearest to known: used, such, defined, well, described, regarded, moreno, possible,
# Nearest to war: logik, bithynia, virgil, murdered, enslaved, interrupts, suspect, haitians,
# Nearest to people: men, students, individuals, kanji, tactically, lips, years, lycos,
# Nearest to these: some, many, several, both, such, those, which, various,
# Nearest to to: would, gasification, could, may, syd, sidewise, might, can,
# Nearest to this: which, it, the, logged, unpaid, that, he, bcd,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Average loss at step 52000: 3.440273
# Average loss at step 54000: 3.425929
# Average loss at step 56000: 3.439482
# Average loss at step 58000: 3.398501
# Average loss at step 60000: 3.388349
# Nearest to an: drummers, another, disrupting, radical, eisenstein, mcgill, clotting, speedway,
# Nearest to history: list, determining, demographics, review, orford, pelagic, auditum, justice,
# Nearest to s: whose, isbn, algorithmic, analyte, although, yield, recite, crammed,
# Nearest to not: you, never, they, almost, still, cheques, now, always,
# Nearest to about: estimated, approximately, greatly, on, discrete, pyrimidine, litre, fostered,
# Nearest to more: less, most, longer, greater, very, faster, rather, catabolism,
# Nearest to during: after, in, although, before, within, since, at, through,
# Nearest to be: been, become, have, refer, are, being, was, seem,
# Nearest to as: using, naiste, beos, strictly, forceful, valuables, dissenters, warship,
# Nearest to known: used, defined, such, regarded, described, well, moreno, possible,
# Nearest to war: logik, bithynia, virgil, gagauz, wars, enslaved, murdered, yalta,
# Nearest to people: men, individuals, students, americans, those, women, lips, jews,
# Nearest to these: many, some, such, several, those, both, they, their,
# Nearest to to: would, fletcher, sidewise, syd, might, could, and, not,
# Nearest to this: it, which, that, there, some, the, unpaid, deceptive,
# Nearest to nine: eight, six, seven, five, four, three, zero, one,
# Average loss at step 62000: 3.238966
# Average loss at step 64000: 3.252420
# Average loss at step 66000: 3.403204
# Average loss at step 68000: 3.397573
# Average loss at step 70000: 3.360012
# Nearest to an: isadora, the, disrupting, radical, speedway, clotting, advised, drummers,
# Nearest to history: review, list, determining, essence, hazards, nigerian, expatriate, encyclopedia,
# Nearest to s: whose, isbn, algorithmic, refutes, concealed, the, gobi, zondervan,
# Nearest to not: now, always, still, never, usually, properly, often, almost,
# Nearest to about: discrete, approximately, estimated, over, on, greatly, pyrimidine, billboards,
# Nearest to more: less, most, very, faster, rather, too, greater, longer,
# Nearest to during: after, before, in, within, until, although, through, at,
# Nearest to be: been, become, being, is, were, have, refer, grudge,
# Nearest to as: hosni, payloads, cleric, sinuous, karaca, exocet, when, tarquin,
# Nearest to known: used, such, defined, regarded, described, well, opposed, possible,
# Nearest to war: virgil, enslaved, wars, bithynia, yalta, logik, baxter, gagauz,
# Nearest to people: students, men, individuals, women, americans, children, orestes, persons,
# Nearest to these: such, some, many, those, several, are, which, both,
# Nearest to to: npd, for, would, can, fic, virtuosic, might, not,
# Nearest to this: which, it, that, the, another, tighten, bengalis, there,
# Nearest to nine: eight, six, seven, five, four, three, zero, one,
# Average loss at step 72000: 3.373740
# Average loss at step 74000: 3.351386
# Average loss at step 76000: 3.319763
# Average loss at step 78000: 3.352426
# Average loss at step 80000: 3.376620
# Nearest to an: neglect, isadora, speedway, advised, intensified, macos, disrupting, restraint,
# Nearest to history: review, list, encyclopedia, campos, development, daytona, immunodeficiency, litmus,
# Nearest to s: isbn, concealed, souvenirs, whose, temps, functionalist, lawyers, hakama,
# Nearest to not: never, still, always, usually, we, now, they, often,
# Nearest to about: approximately, over, discrete, greatly, estimated, chemically, wind, weasels,
# Nearest to more: less, very, most, faster, rather, too, longer, highly,
# Nearest to during: after, before, in, when, within, although, until, through,
# Nearest to be: been, have, become, being, refer, seem, were, are,
# Nearest to as: romanorum, when, naiste, generosity, before, mackerel, minimising, using,
# Nearest to known: used, regarded, defined, such, opposed, described, depicted, moreno,
# Nearest to war: wars, enslaved, yalta, printings, arrange, virgil, bithynia, deadliest,
# Nearest to people: men, students, individuals, children, women, persons, americans, someone,
# Nearest to these: those, several, many, both, such, various, some, they,
# Nearest to to: syd, gasification, would, legally, malibu, toward, towards, must,
# Nearest to this: which, it, the, logged, there, another, euthanasia, that,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Average loss at step 82000: 3.408870
# Average loss at step 84000: 3.412049
# Average loss at step 86000: 3.390470
# Average loss at step 88000: 3.349332
# Average loss at step 90000: 3.367860
# Nearest to an: disrupting, speedway, neglect, mcgill, isadora, eisenstein, tendons, intensified,
# Nearest to history: list, review, campos, development, encyclopedia, politics, auditum, essence,
# Nearest to s: isbn, his, whose, activist, temps, gomorrah, sequels, analyte,
# Nearest to not: still, never, now, generally, cheques, usually, always, fermented,
# Nearest to about: approximately, weasels, over, pyrimidine, billboards, discrete, assuring, boneyard,
# Nearest to more: less, very, most, rather, faster, cheaper, highly, longer,
# Nearest to during: after, in, through, before, within, at, until, while,
# Nearest to be: become, been, lead, seem, being, was, refer, is,
# Nearest to as: finches, beep, hosni, hartmann, gladius, ethel, cleric, minimising,
# Nearest to known: used, regarded, defined, such, described, opposed, possible, moreno,
# Nearest to war: wars, enslaved, tombstone, bithynia, arrange, yalta, flavour, deadliest,
# Nearest to people: men, students, women, children, americans, individuals, persons, members,
# Nearest to these: several, some, those, many, such, various, both, which,
# Nearest to to: will, would, gasification, towards, almohades, for, must, virtuosic,
# Nearest to this: it, which, the, some, any, another, logged, lehi,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Average loss at step 92000: 3.397782
# Average loss at step 94000: 3.256374
# Average loss at step 96000: 3.359802
# Average loss at step 98000: 3.241676
# Average loss at step 100000: 3.357508
# Nearest to an: isadora, speedway, another, neglect, advised, eisenstein, drummers, macos,
# Nearest to history: list, review, development, hazards, realplayer, aeon, madam, campos,
# Nearest to s: whose, his, isbn, my, the, conducts, condenses, brokers,
# Nearest to not: now, never, still, generally, almost, always, cheques, considered,
# Nearest to about: approximately, pyrimidine, weasels, buyers, billboards, assuring, estimated, geddes,
# Nearest to more: less, most, very, faster, greater, cheaper, quite, rather,
# Nearest to during: in, after, at, before, through, within, until, following,
# Nearest to be: been, have, become, is, being, are, seem, frost,
# Nearest to as: battling, naiste, like, beep, minimising, when, ethel, exocet,
# Nearest to known: used, defined, regarded, possible, such, described, opposed, depicted,
# Nearest to war: wars, enslaved, baxter, yalta, deadliest, tombstone, bithynia, diabetics,
# Nearest to people: men, students, women, children, individuals, americans, persons, players,
# Nearest to these: some, several, many, those, all, various, which, such,
# Nearest to to: will, could, would, must, can, fletcher, should, towards,
# Nearest to this: which, it, the, another, what, logged, some, he,
# Nearest to nine: eight, seven, six, four, five, three, zero, one,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_continuous_bag_of_batch(batch_size, window):
    global data_index
    batch = np.ndarray(shape=(batch_size, window*2), dtype=np.ndarray)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)

    for i in range(batch_size):
        midpoint = data_index + window
        batch[i] = np.array(data[data_index:midpoint] + data[midpoint+1:midpoint+window+1])
        labels[i] = data[midpoint]
        data_index = (data_index + 1) % (len(data) - window * 2 - 2)
            
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:9]])

for window_size in [2, 4]:
    data_index = 0
    batch, labels = generate_continuous_bag_of_batch(20, window_size)
    print('\nwith window = %d' % (window_size))
    print('    batch:', [reverse_dictionary[bi] for bi in batch[0]])
    print('    labels:', reverse_dictionary[labels[0][0]])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with window = 2
#     batch: ['anarchism', 'originated', 'a', 'term']
#     labels: as
#
# with window = 4
#     batch: ['anarchism', 'originated', 'as', 'a', 'of', 'abuse', 'first', 'used']
#     labels: term

# %%
batch_size = 128
embedding_size = 1024 # Dimension of the embedding vector.
window_size = 5
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 128 # Number of negative examples to sample.

for sample in valid_examples:
    print(reverse_dictionary[sample], end=', ')

graph = tf.Graph()

with graph.as_default():

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, window_size*2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    avg_embed =  tf.reduce_mean(embed, 1, keep_dims=False)
    # Compute the softmax loss, using a sample of the negative labels each time.
    soft_loss = tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, avg_embed, train_labels, num_sampled, vocabulary_size)
    loss = tf.reduce_mean(soft_loss)

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# which, into, seven, at, may, b, who, can, it, th, have, zero, often, and, war, there,
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-d302016664d0> in <module>()
#      32     avg_embed =  tf.reduce_mean(embed, 1, keep_dims=False)
#      33     # Compute the softmax loss, using a sample of the negative labels each time.
# ---> 34     soft_loss = tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, avg_embed, train_labels, num_sampled, vocabulary_size)
#      35     loss = tf.reduce_mean(soft_loss)
#      36
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/nn_impl.pyc in sampled_softmax_loss(weights, biases, labels, inputs, num_sampled, num_classes, num_true, sampled_values, remove_accidental_hits, partition_strategy, name)
#    1189       remove_accidental_hits=remove_accidental_hits,
#    1190       partition_strategy=partition_strategy,
# -> 1191       name=name)
#    1192   sampled_losses = nn_ops.softmax_cross_entropy_with_logits(labels=labels,
#    1193                                                             logits=logits)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/nn_impl.pyc in _compute_sampled_logits(weights, biases, labels, inputs, num_sampled, num_classes, num_true, sampled_values, subtract_log_q, remove_accidental_hits, partition_strategy, name)
#     972     row_wise_dots = math_ops.multiply(
#     973         array_ops.expand_dims(inputs, 1),
# --> 974         array_ops.reshape(true_w, new_true_w_shape))
#     975     # We want the row-wise dot plus biases which yields a
#     976     # [batch_size, num_true] tensor of true_logits.
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/math_ops.pyc in multiply(x, y, name)
#     355
#     356 def multiply(x, y, name=None):
# --> 357   return gen_math_ops._mul(x, y, name)
#     358 multiply.__doc__ = gen_math_ops._mul.__doc__.replace("Mul", "`tf.multiply`")
#     359
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/gen_math_ops.pyc in _mul(x, y, name)
#    1623     A `Tensor`. Has the same type as `x`.
#    1624   """
# -> 1625   result = _op_def_lib.apply_op("Mul", x=x, y=y, name=name)
#    1626   return result
#    1627
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/op_def_library.pyc in apply_op(self, op_type_name, name, **keywords)
#     520                   "%s type %s of argument '%s'." %
#     521                   (prefix, dtypes.as_dtype(attrs[input_arg.type_attr]).name,
# --> 522                    inferred_from[input_arg.type_attr]))
#     523
#     524           types = [values.dtype]
#
# TypeError: Input 'y' of 'Mul' Op has type float32 that does not match type int32 of argument 'x'.

# %%
num_steps = 1000001
print_step = 10000
summary_step = 100000

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_continuous_bag_of_batch(
            batch_size, window_size)
        feed_dict = {train_dataset: batch_data, train_labels: batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % print_step == 0:
            if step > 0:
                average_loss = average_loss / print_step
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % summary_step == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-a4d82992e424> in <module>()
#      11             batch_size, window_size)
#      12         feed_dict = {train_dataset: batch_data, train_labels: batch_labels}
# ---> 13         _, l = session.run([optimizer, loss], feed_dict=feed_dict)
#      14         average_loss += l
#      15         if step % print_step == 0:
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     950
#     951     # Create a fetch handler to take care of the structure of fetches.
# --> 952     fetch_handler = _FetchHandler(self._graph, fetches, feed_dict_string)
#     953
#     954     # Run request and get response.
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in __init__(self, graph, fetches, feeds)
#     406     """
#     407     with graph.as_default():
# --> 408       self._fetch_mapper = _FetchMapper.for_fetch(fetches)
#     409     self._fetches = []
#     410     self._targets = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in for_fetch(fetch)
#     228     elif isinstance(fetch, (list, tuple)):
#     229       # NOTE(touts): This is also the code path for namedtuples.
# --> 230       return _ListFetchMapper(fetch)
#     231     elif isinstance(fetch, dict):
#     232       return _DictFetchMapper(fetch)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in __init__(self, fetches)
#     335     """
#     336     self._fetch_type = type(fetches)
# --> 337     self._mappers = [_FetchMapper.for_fetch(fetch) for fetch in fetches]
#     338     self._unique_fetches, self._value_indices = _uniquify_fetches(self._mappers)
#     339
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in for_fetch(fetch)
#     236         if isinstance(fetch, tensor_type):
#     237           fetches, contraction_fn = fetch_fn(fetch)
# --> 238           return _ElementFetchMapper(fetches, contraction_fn)
#     239     # Did not find anything.
#     240     raise TypeError('Fetch argument %r has invalid type %r' %
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in __init__(self, fetches, contraction_fn)
#     272       except ValueError as e:
#     273         raise ValueError('Fetch argument %r cannot be interpreted as a '
# --> 274                          'Tensor. (%s)' % (fetch, str(e)))
#     275       except KeyError as e:
#     276         raise ValueError('Fetch argument %r cannot be interpreted as a '
#
# ValueError: Fetch argument <tf.Operation 'Adagrad' type=NoOp> cannot be interpreted as a Tensor. (Operation name: "Adagrad"
# op: "NoOp"
# input: "^Adagrad/update_Variable/SparseApplyAdagrad"
# input: "^Adagrad/update_Variable_1/SparseApplyAdagrad"
# input: "^Adagrad/update_Variable_2/SparseApplyAdagrad"
# device: "/device:CPU:0"
#  is not an element of this graph.)

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
